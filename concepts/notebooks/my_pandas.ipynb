# %%
import pandas as pd

# %%
df = pd.DataFrame({"outlier": [0, 1, 0, 0, 1, 1, 1, 0], "trip": [0, 0, 0, 0, 1, 1, 1, 1]})
df
# Out:
#    outlier  trip
# 0        0     0
# 1        1     0
# 2        0     0
# 3        0     0
# 4        1     1
# 5        1     1
# 6        1     1
# 7        0     1

# %%
df.groupby(by="trip")["outlier"].diff()
# Out:
# 0    NaN
# 1    1.0
# 2   -1.0
# 3    0.0
# 4    NaN
# 5    0.0
# 6    0.0
# 7   -1.0
# Name: outlier, dtype: float64

# %%
df["to_delete"] = df.groupby(by="trip")["outlier"].diff() == -1
df
# Out:
#    outlier  trip  to_delete
# 0        0     0      False
# 1        1     0      False
# 2        0     0       True
# 3        0     0      False
# 4        1     1      False
# 5        1     1      False
# 6        1     1      False
# 7        0     1       True

# %%
mb = 9.56 / (1 + (-9.54 / 100) )
mb
# Out:
# 10.568206942294937

# %%
sc = 84.8 / (1 + (12.3 / 100) )
sc
# Out:
# 75.5120213713268

# %%
4 * sc - 21 * mb
# Out:
# 80.1157396971135

# %%
10 * 9.56
# Out:
# 95.60000000000001

# %%
25 * 4
# Out:
# 100

# %%
st_v = 3*122.18
st_v # 3 eggs
# Out:
# 366.54

# %%
sum1 = 400 - st_v

# %%
# 2 eggs, 70 stones
sum1 = sum1 + 2 * 115.89 + 70 * 0.99
sum1
# Out:
# 334.54

# %%
400 / 1.99
# Out:
# 201.00502512562815

# %%
4000 * 7 / 7000
# Out:
# 4.0

# %%
df = pd.DataFrame({"u_r": [100, 34.4,	24.4,	20.3,	17.9,	16.4,	15.4,	14.6], 
                "arp": [0.45,	0.43,	0.46,	0.45,	0.43,	0.47,	0.46,	0.45]})

# %%
(df["u_r"] * df["arp"]).sum() / 100
# Out:
# 1.0921
